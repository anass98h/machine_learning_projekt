# %% [markdown]
# ## SVM Classification
#
# ###  Grid Search Results
# - Best Parameters: {'clf__C': 10, 'clf__gamma': 0.1, 'clf__kernel': 'rbf'}
# - Best CV Score: 0.9637
#
# ### Test Set Evaluation
# - Accuracy: 0.9734
# - Error Rate: 0.0266
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)
#
# ## SVM regression
#
# - Best parameters {'C': 0.5,  'gamma': 0.01, 'kernel': 'rbf'}
# - mean CV R2:  0.6556650295277084
# - Test R2: 0.7313672348692017
# - Test MSE: 0.016039296276012784
#
# ![image-5.png](attachment:image-5.png)
# ![image-6.png](attachment:image-6.png)
