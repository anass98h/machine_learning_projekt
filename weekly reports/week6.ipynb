# %% [markdown]
# # Week 6
#
# ---
#
# ## 1. Improving ensembles
#
# ### 1.1 Classification ensemble
#
# We added three different tree-based models to our ensemble.
#
# Our ensemble now consists of five models:
#
# * KNN
# * Logistic Regression
# * **Bagging Tree**
# * **Random Forest**
# * **Boosting Tree**
#
# These are the results:
#
# - **Voting Ensemble**:
#   - CV Mean Accuracy: 0.945437407018509
#   - CV Std Accuracy: 0.006907042204880505
#   - Test Accuracy: 0.9518140589569161
# - **Stacking Ensemble:**
#   - CV Mean Accuracy: 0.9638608424700301
#   - CV Std Accuracy: 0.004411976272010811
#   - Test Accuracy: **0.9767573696145124**
#
# ![image.png](attachment:image.png)
#
# **Observation:**
# Both ensemble methods were significantly improved by including the tree-based models. The new stacking ensemble is now our strongest classifier model with an accuracy of 97.6%.
#
# ### 1.2 Regression ensemble
#
# We already included bagging trees and random forest last week. This week, we attempted to add a boosting tree. However, after evaluating its performance, we observed no significant improvement in accuracy.
#
#
# ## 2. Improving linear regression model
#
# Enhancement: We evaluated the cubic fit for every feature against the predictor. By creating new columns that contained the cube of each feature.
#
# Performance Gains:
#
# - **Old Champion Model:**
#     - MSE: 0.01971761590591921
#     - R²: 0.6697612169858351
# - **New Champion Model:**
#     - MSE: 0.018126428270177134
#     - R²: 0.6964110853513561
#
# ![image-3.png](attachment:image-3.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Sofware Development - Code Quality And Deployment Report
#
# ## Overview
#
# We have successfully implemented SonarQube for our multi-module project, consisting of three main components: Frontend, Backend, and ML. This implementation has enabled us to track code quality metrics and test coverage across all components of our application.
#
# ## Implementation Details
#
# ### Configuration
# We've set up separate SonarQube projects for each component to optimize analysis and reporting:
# - `MLProject2-frontend`: JavaScript/React frontend
# - `MLProject2-backend`: Python FastAPI backend
# - `MLProject2-ml`: Python ML models and algorithms, including stacking tree ensemble
#
# ## ML Model Deployment
# We have successfully deployed our new stacking tree ensemble model. This advanced machine learning model:
#
#
# ### Key Metrics Being Tracked(Work in-progress)
# - Coverage
#
# ## Results
#
# ![image.png](attachment:image.png)
#
# ### Coverage Improvement
# We have significantly improved our test coverage across the codebase:
#
# | Component | Initial Coverage | Current Coverage | Improvement |
# |-----------|------------------|-----------------|-------------|
# | Overall   | 12.7%            | 54.3%           | 41.6%       |
# | Backend   | 0%               | 65.6%           | 65.6%       |
# | ML        | 12.7%            | 47.8%           | 35.1%       |
# | Frontend  | 0%               | 49.6%           | 49.6%       |
